# %% [markdown]
# # Игра угадай число

# %%
from game_v2 import score_game
from game_v2 import random_predict

# %% [markdown]
# ## Угадываем рандомно

# %%
score_game(random_predict)
# Out:
# Число угадано за 6 попыток, число было 92
# Число угадано за 7 попыток, число было 58
# Число угадано за 5 попыток, число было 46
# Число угадано за 4 попыток, число было 43
# Число угадано за 2 попыток, число было 75
# Число угадано за 3 попыток, число было 11
# Число угадано за 7 попыток, число было 16
# Число угадано за 6 попыток, число было 28
# Число угадано за 5 попыток, число было 46
# Число угадано за 7 попыток, число было 100
# Число угадано за 6 попыток, число было 60
# Число угадано за 7 попыток, число было 61
# Число угадано за 7 попыток, число было 80
# Число угадано за 4 попыток, число было 30
# Число угадано за 7 попыток, число было 70
# Число угадано за 6 попыток, число было 79
# Число угадано за 6 попыток, число было 41
# Число угадано за 7 попыток, число было 26
# Число угадано за 7 попыток, число было 64
# Число угадано за 7 попыток, число было 85
# Число угадано за 7 попыток, число было 49
# Число угадано за 7 попыток, число было 74
# ...
